# %%
from os.path import join
from os import sep, getcwd, chdir
#import json
from tqdm import tqdm
#from OverlappingCommunitiesFetcher import OverlappingCommunitiesFetcher
#from RedditAnomalyInfuser import create_experiment_networks

# %%
# Imports from parent directory
original_cur_dir = getcwd()
chdir('..')
from Experiment import perform_all_experiments
from Config import DETECTOR_CONFIG, DETECTION_CONFIG, NUM_ANOM_COMMS
# Go back to current directory
chdir(original_cur_dir)
# Out:
# C:\Users\lapid\notebook\Thesis\GenericAnomalousCommunitiesDetection\AnomalousCommunityDetection\FeatureExtractor.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# # General configuration

# %%
EXPERIMENT_DIR_PATH = 'Experiment'
baselines = ['avg_degree', 'cut_ratio', 'conductance', 'flake_odf', 'avg_odf', 'unattr_amen']
exclude_amen = False
max_experiments = 5

# %% [markdown]
# # Conduct Experiment

# %%
perform_all_experiments(
    experiment_dir=EXPERIMENT_DIR_PATH,
    detector_config=DETECTOR_CONFIG,
    detection_config=DETECTION_CONFIG,
    num_anom_comms=NUM_ANOM_COMMS,
    baselines=baselines,
    exclude_amen=exclude_amen,
    max_experiments=max_experiments,
    dir_idx_tuple=(0, 10))
# Out:
# ['ErdosRenyi_p0.05_k[1,1]_m0.01', 'ErdosRenyi_p0.05_k[1,1]_m0.02', 'ErdosRenyi_p0.05_k[1,1]_m0.04', 'ErdosRenyi_p0.05_k[1,1]_m0.08', 'ErdosRenyi_p0.05_k[1,1]_m0.16', 'ErdosRenyi_p0.10_k[1,1]_m0.01', 'ErdosRenyi_p0.10_k[1,1]_m0.02', 'ErdosRenyi_p0.10_k[1,1]_m0.04', 'ErdosRenyi_p0.10_k[1,1]_m0.08', 'ErdosRenyi_p0.10_k[1,1]_m0.16']
#
# ################
# ################
# 	Beginning "ErdosRenyi_p0.05_k[1,1]_m0.01" experiments directory...
# ################
# ################
#
#
# ########
# 	Beginning size group "min" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9272
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9292
# 	Total number of edges: 9382
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 40821
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 40921
# 	Total number of edges: 43312
#
# Extracting positive edges features...
#   0%|          | 0/9382 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9382 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/43312 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1884 | 0    |
#      True      |-------------|
#             1  | 31   | 1838 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 39851
# 	predicted_not_exist: 3461
# 	predicted_ratio: 0.920
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:06:52.003757
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13453
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13473
# 	Total number of edges: 13655
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 41550
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 41650
# 	Total number of edges: 43884
#
# Extracting positive edges features...
#   0%|          | 0/13655 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13655 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/43884 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.988
# 	F1        : 0.988
# 	ROC AUC   : 0.988
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2746 | 0    |
#      True      |-------------|
#             1  | 61   | 2655 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 39220
# 	predicted_not_exist: 4664
# 	predicted_ratio: 0.893
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:15:04.424794
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 7993
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8013
# 	Total number of edges: 8078
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 46678
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 46778
# 	Total number of edges: 49611
#
# Extracting positive edges features...
#   0%|          | 0/8078 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8078 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/49611 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1594 | 0    |
#      True      |-------------|
#             1  | 24   | 1614 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 44864
# 	predicted_not_exist: 4747
# 	predicted_ratio: 0.904
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:24:14.279751
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 11931
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 11951
# 	Total number of edges: 12099
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 46987
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 47087
# 	Total number of edges: 49795
#
# Extracting positive edges features...
#   0%|          | 0/12099 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12099 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/49795 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2412 | 0    |
#      True      |-------------|
#             1  | 42   | 2386 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 45102
# 	predicted_not_exist: 4693
# 	predicted_ratio: 0.905
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:33:46.290751
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10315
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10335
# 	Total number of edges: 10425
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 47445
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 47545
# 	Total number of edges: 50339
#
# Extracting positive edges features...
#   0%|          | 0/10425 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10425 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/50339 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.995
# 	ROC AUC   : 0.995
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2048 | 0    |
#      True      |-------------|
#             1  | 21   | 2101 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 45088
# 	predicted_not_exist: 5251
# 	predicted_ratio: 0.895
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:43:37.148804
#
# ########
# 	Beginning size group "quantile10" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9276
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9296
# 	Total number of edges: 9386
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 41451
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 41551
# 	Total number of edges: 43968
#
# Extracting positive edges features...
#   0%|          | 0/9386 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9386 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/43968 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1870 | 0    |
#      True      |-------------|
#             1  | 29   | 1856 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 40442
# 	predicted_not_exist: 3526
# 	predicted_ratio: 0.919
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:07:40.141966
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13462
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13482
# 	Total number of edges: 13665
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 42645
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 42745
# 	Total number of edges: 45020
#
# Extracting positive edges features...
#   0%|          | 0/13665 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13665 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/45020 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.990
# 	F1        : 0.990
# 	ROC AUC   : 0.990
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2746 | 0    |
#      True      |-------------|
#             1  | 50   | 2670 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 40290
# 	predicted_not_exist: 4730
# 	predicted_ratio: 0.894
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:15:46.783184
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 8000
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8020
# 	Total number of edges: 8080
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 47415
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 47515
# 	Total number of edges: 50381
#
# Extracting positive edges features...
#   0%|          | 0/8080 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8080 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/50381 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1601 | 0    |
#      True      |-------------|
#             1  | 17   | 1614 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 44977
# 	predicted_not_exist: 5404
# 	predicted_ratio: 0.892
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:25:02.928324
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 11934
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 11954
# 	Total number of edges: 12102
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 47551
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 47651
# 	Total number of edges: 50386
#
# Extracting positive edges features...
#   0%|          | 0/12102 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12102 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/50386 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2432 | 0    |
#      True      |-------------|
#             1  | 40   | 2369 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 46044
# 	predicted_not_exist: 4342
# 	predicted_ratio: 0.913
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:34:32.800985
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10325
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10345
# 	Total number of edges: 10435
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 48722
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 48822
# 	Total number of edges: 51666
#
# Extracting positive edges features...
#   0%|          | 0/10435 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10435 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/51666 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2100 | 0    |
#      True      |-------------|
#             1  | 23   | 2051 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 46319
# 	predicted_not_exist: 5347
# 	predicted_ratio: 0.896
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:44:22.224473
#
# ########
# 	Beginning size group "quartile1" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9289
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9309
# 	Total number of edges: 9399
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 42253
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 42353
# 	Total number of edges: 44796
#
# Extracting positive edges features...
#   0%|          | 0/9399 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9399 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/44796 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.993
# 	ROC AUC   : 0.993
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1859 | 0    |
#      True      |-------------|
#             1  | 26   | 1875 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 41480
# 	predicted_not_exist: 3316
# 	predicted_ratio: 0.925
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:07:42.546588
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13477
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13497
# 	Total number of edges: 13679
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 43590
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 43690
# 	Total number of edges: 45999
#
# Extracting positive edges features...
#   0%|          | 0/13679 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13679 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/45999 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.990
# 	F1        : 0.990
# 	ROC AUC   : 0.990
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2722 | 0    |
#      True      |-------------|
#             1  | 54   | 2696 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 41423
# 	predicted_not_exist: 4576
# 	predicted_ratio: 0.900
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:15:53.800135
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 8005
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8025
# 	Total number of edges: 8090
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 48333
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 48433
# 	Total number of edges: 51339
#
# Extracting positive edges features...
#   0%|          | 0/8090 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8090 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/51339 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.993
# 	ROC AUC   : 0.993
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1631 | 0    |
#      True      |-------------|
#             1  | 21   | 1584 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 46532
# 	predicted_not_exist: 4807
# 	predicted_ratio: 0.906
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:25:20.740863
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 11942
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 11962
# 	Total number of edges: 12110
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 48645
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 48745
# 	Total number of edges: 51529
#
# Extracting positive edges features...
#   0%|          | 0/12110 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12110 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/51529 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.993
# 	ROC AUC   : 0.993
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2436 | 0    |
#      True      |-------------|
#             1  | 33   | 2375 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 46669
# 	predicted_not_exist: 4860
# 	predicted_ratio: 0.905
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:35:11.328738
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10326
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10346
# 	Total number of edges: 10436
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 49340
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 49440
# 	Total number of edges: 52314
#
# Extracting positive edges features...
#   0%|          | 0/10436 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10436 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/52314 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2135 | 0    |
#      True      |-------------|
#             1  | 31   | 2009 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 46780
# 	predicted_not_exist: 5534
# 	predicted_ratio: 0.894
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:45:20.983298
#
# ########
# 	Beginning size group "median" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9299
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9319
# 	Total number of edges: 9409
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 43572
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 43672
# 	Total number of edges: 46171
#
# Extracting positive edges features...
#   0%|          | 0/9409 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9409 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/46171 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1896 | 0    |
#      True      |-------------|
#             1  | 28   | 1840 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 42683
# 	predicted_not_exist: 3488
# 	predicted_ratio: 0.924
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:07:54.762867
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13499
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13519
# 	Total number of edges: 13701
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 44930
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 45030
# 	Total number of edges: 47385
#
# Extracting positive edges features...
#   0%|          | 0/13701 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13701 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/47385 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.989
# 	F1        : 0.989
# 	ROC AUC   : 0.989
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2705 | 0    |
#      True      |-------------|
#             1  | 56   | 2720 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 42723
# 	predicted_not_exist: 4662
# 	predicted_ratio: 0.901
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:16:17.806560
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 8009
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8029
# 	Total number of edges: 8095
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 49989
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 50089
# 	Total number of edges: 53075
#
# Extracting positive edges features...
#   0%|          | 0/8095 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8095 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/53075 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.993
# 	ROC AUC   : 0.993
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1603 | 0    |
#      True      |-------------|
#             1  | 22   | 1613 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 48063
# 	predicted_not_exist: 5012
# 	predicted_ratio: 0.905
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:26:06.142971
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 11959
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 11979
# 	Total number of edges: 12127
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 50588
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 50688
# 	Total number of edges: 53552
#
# Extracting positive edges features...
#   0%|          | 0/12127 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12127 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/53552 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2423 | 0    |
#      True      |-------------|
#             1  | 40   | 2388 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 49223
# 	predicted_not_exist: 4329
# 	predicted_ratio: 0.919
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:36:13.278168
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10348
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10368
# 	Total number of edges: 10458
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 51189
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 51289
# 	Total number of edges: 54234
#
# Extracting positive edges features...
#   0%|          | 0/10458 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10458 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/54234 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2127 | 0    |
#      True      |-------------|
#             1  | 24   | 2033 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 48646
# 	predicted_not_exist: 5588
# 	predicted_ratio: 0.896
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:46:37.362244
#
# ########
# 	Beginning size group "random" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9306
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9326
# 	Total number of edges: 9416
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 44572
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 44672
# 	Total number of edges: 47214
#
# Extracting positive edges features...
#   0%|          | 0/9416 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9416 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/47214 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.995
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1859 | 0    |
#      True      |-------------|
#             1  | 19   | 1889 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 43482
# 	predicted_not_exist: 3732
# 	predicted_ratio: 0.920
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:08:21.440171
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13490
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13510
# 	Total number of edges: 13692
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 45440
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 45540
# 	Total number of edges: 47930
#
# Extracting positive edges features...
#   0%|          | 0/13692 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13692 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/47930 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.990
# 	F1        : 0.990
# 	ROC AUC   : 0.990
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2728 | 0    |
#      True      |-------------|
#             1  | 54   | 2695 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 43307
# 	predicted_not_exist: 4623
# 	predicted_ratio: 0.903
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:17:06.695656
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 8019
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8039
# 	Total number of edges: 8105
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 51516
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 51616
# 	Total number of edges: 54666
#
# Extracting positive edges features...
#   0%|          | 0/8105 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8105 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/54666 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1602 | 0    |
#      True      |-------------|
#             1  | 29   | 1611 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 49801
# 	predicted_not_exist: 4865
# 	predicted_ratio: 0.911
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:27:43.759657
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 11976
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 11996
# 	Total number of edges: 12144
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 51538
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 51638
# 	Total number of edges: 54531
#
# Extracting positive edges features...
#   0%|          | 0/12144 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12144 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/54531 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2454 | 0    |
#      True      |-------------|
#             1  | 37   | 2367 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 49545
# 	predicted_not_exist: 4986
# 	predicted_ratio: 0.908
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:38:34.607786
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10359
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10379
# 	Total number of edges: 10469
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 52025
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 52125
# 	Total number of edges: 55101
#
# Extracting positive edges features...
#   0%|          | 0/10469 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10469 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/55101 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2098 | 0    |
#      True      |-------------|
#             1  | 24   | 2066 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 49680
# 	predicted_not_exist: 5421
# 	predicted_ratio: 0.901
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:49:24.419026
#
# ################
# ################
# 	Beginning "ErdosRenyi_p0.05_k[1,1]_m0.02" experiments directory...
# ################
# ################
#
#
# ########
# 	Beginning size group "min" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9272
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9292
# 	Total number of edges: 9382
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 40821
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 40921
# 	Total number of edges: 43312
#
# Extracting positive edges features...
#   0%|          | 0/9382 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9382 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/43312 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.993
# 	ROC AUC   : 0.993
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1886 | 0    |
#      True      |-------------|
#             1  | 23   | 1844 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 39851
# 	predicted_not_exist: 3461
# 	predicted_ratio: 0.920
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:07:26.390955
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13453
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13473
# 	Total number of edges: 13655
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 41550
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 41650
# 	Total number of edges: 43884
#
# Extracting positive edges features...
#   0%|          | 0/13655 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13655 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/43884 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.990
# 	F1        : 0.990
# 	ROC AUC   : 0.990
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2706 | 0    |
#      True      |-------------|
#             1  | 54   | 2702 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 39350
# 	predicted_not_exist: 4534
# 	predicted_ratio: 0.896
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:15:11.568966
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 7993
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8013
# 	Total number of edges: 8078
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 46678
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 46778
# 	Total number of edges: 49611
#
# Extracting positive edges features...
#   0%|          | 0/8078 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8078 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/49611 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1638 | 0    |
#      True      |-------------|
#             1  | 19   | 1575 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 44864
# 	predicted_not_exist: 4747
# 	predicted_ratio: 0.904
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:24:19.897291
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 11931
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 11951
# 	Total number of edges: 12099
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 46987
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 47087
# 	Total number of edges: 49795
#
# Extracting positive edges features...
#   0%|          | 0/12099 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12099 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/49795 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.990
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2488 | 0    |
#      True      |-------------|
#             1  | 42   | 2310 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 45102
# 	predicted_not_exist: 4693
# 	predicted_ratio: 0.905
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:33:45.876686
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10315
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10335
# 	Total number of edges: 10425
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 47445
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 47545
# 	Total number of edges: 50339
#
# Extracting positive edges features...
#   0%|          | 0/10425 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10425 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/50339 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2124 | 0    |
#      True      |-------------|
#             1  | 21   | 2025 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 45049
# 	predicted_not_exist: 5290
# 	predicted_ratio: 0.894
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:43:27.214690
#
# ########
# 	Beginning size group "quantile10" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9276
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9296
# 	Total number of edges: 9386
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 41451
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 41551
# ...
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:33:42.431453
#
# ########
# 	Beginning size group "median" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9321
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9341
# 	Total number of edges: 9431
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 43572
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 43672
# 	Total number of edges: 46303
#
# Extracting positive edges features...
#   0%|          | 0/9431 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9431 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/46303 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1883 | 0    |
#      True      |-------------|
#             1  | 31   | 1859 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 42418
# 	predicted_not_exist: 3885
# 	predicted_ratio: 0.916
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:06:15.639387
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13531
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13551
# 	Total number of edges: 13733
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 44930
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 45030
# 	Total number of edges: 47538
#
# Extracting positive edges features...
#   0%|          | 0/13733 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13733 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/47538 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.988
# 	F1        : 0.988
# 	ROC AUC   : 0.988
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2740 | 0    |
#      True      |-------------|
#             1  | 63   | 2691 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 42357
# 	predicted_not_exist: 5181
# 	predicted_ratio: 0.891
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:12:58.132765
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 8036
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8056
# 	Total number of edges: 8122
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 49989
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 50089
# 	Total number of edges: 53243
#
# Extracting positive edges features...
#   0%|          | 0/8122 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8122 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/53243 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.991
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1608 | 0    |
#      True      |-------------|
#             1  | 26   | 1615 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 47927
# 	predicted_not_exist: 5316
# 	predicted_ratio: 0.900
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:21:01.827243
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 12007
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 12027
# 	Total number of edges: 12175
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 50588
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 50688
# 	Total number of edges: 53715
#
# Extracting positive edges features...
#   0%|          | 0/12175 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12175 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/53715 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2499 | 0    |
#      True      |-------------|
#             1  | 34   | 2337 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 48416
# 	predicted_not_exist: 5299
# 	predicted_ratio: 0.901
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:29:23.012373
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10389
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10409
# 	Total number of edges: 10499
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 51189
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 51289
# 	Total number of edges: 54397
#
# Extracting positive edges features...
#   0%|          | 0/10499 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10499 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/54397 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2063 | 0    |
#      True      |-------------|
#             1  | 25   | 2112 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 48409
# 	predicted_not_exist: 5988
# 	predicted_ratio: 0.889
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:37:55.519075
#
# ########
# 	Beginning size group "random" experiment...
# ########
#
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 9342
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 9362
# 	Total number of edges: 9452
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 44572
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 44672
# 	Total number of edges: 47383
#
# Extracting positive edges features...
#   0%|          | 0/9452 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/9452 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/47383 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.993
# 	F1        : 0.993
# 	ROC AUC   : 0.993
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1814 | 0    |
#      True      |-------------|
#             1  | 26   | 1941 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 43343
# 	predicted_not_exist: 4040
# 	predicted_ratio: 0.914
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 0. Elpased time: 0:07:18.636231
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 13547
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 13567
# 	Total number of edges: 13749
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 45440
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 45540
# 	Total number of edges: 48084
#
# Extracting positive edges features...
#   0%|          | 0/13749 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/13749 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/48084 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.991
# 	ROC AUC   : 0.991
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2765 | 0    |
#      True      |-------------|
#             1  | 44   | 2691 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 42812
# 	predicted_not_exist: 5272
# 	predicted_ratio: 0.890
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 1. Elpased time: 0:15:11.044830
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 8072
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 8092
# 	Total number of edges: 8158
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 51516
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 51616
# 	Total number of edges: 54886
#
# Extracting positive edges features...
#   0%|          | 0/8158 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/8158 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/54886 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.996
# 	F1        : 0.995
# 	ROC AUC   : 0.995
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 1655 | 0    |
#      True      |-------------|
#             1  | 13   | 1596 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 48804
# 	predicted_not_exist: 6082
# 	predicted_ratio: 0.889
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 2. Elpased time: 0:25:35.286514
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 12041
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 12061
# 	Total number of edges: 12209
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 51538
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 51638
# 	Total number of edges: 54728
#
# Extracting positive edges features...
#   0%|          | 0/12209 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/12209 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/54728 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.992
# 	F1        : 0.992
# 	ROC AUC   : 0.992
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2433 | 0    |
#      True      |-------------|
#             1  | 35   | 2416 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 49430
# 	predicted_not_exist: 5298
# 	predicted_ratio: 0.903
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 3. Elpased time: 0:36:10.450942
# Train BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 10398
# 	Number of 'Community'-partite vertices: 20
# 	Total number of vertices: 10418
# 	Total number of edges: 10508
# Test BiPartite network properties:
# 	Number of 'Vertex'-partite vertices: 52025
# 	Number of 'Community'-partite vertices: 100
# 	Total number of vertices: 52125
# 	Total number of edges: 55307
#
# Extracting positive edges features...
#   0%|          | 0/10508 [00:00<?, ?it/s]
# Extracting negative edges features...
#   0%|          | 0/10508 [00:00<?, ?it/s]
# Extracting positive edges features...
#   0%|          | 0/55307 [00:00<?, ?it/s]
# Extracting negative edges features...
# 0it [00:00, ?it/s]
# Validation scores:
# 	Precision : 1.0
# 	Accuracy  : 0.994
# 	F1        : 0.994
# 	ROC AUC   : 0.994
#
#                   Predicted
#                    0     1
#                 -------------
#             0  | 2111 | 0    |
#      True      |-------------|
#             1  | 23   | 2070 |
#                 -------------
#
# Test set edge existence predictions:
# 	predicted_exist: 49366
# 	predicted_not_exist: 5941
# 	predicted_ratio: 0.892
# Ranking by "avg_degree"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "cut_ratio"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "conductance"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "flake_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "avg_odf"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ranking by "unattr_amen"...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finished experiment 4. Elpased time: 0:46:09.454132
