# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple'] * 10
for i, (sample_idx, sample_class, *sample_time_series) in enumerate(samples_df.itertuples()):
    ax = plt.subplot(num_classes, samples_per_class, i + 1)
    ax.plot(range(len(sample_time_series)), sample_time_series, c=colors[sample_class-1])
    axxticks
    plt.title(f"Sample {sample_idx}, class {sample_class}", fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fc0701273bc9> in <module>
#       1 colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple'] * 10
# ----> 2 for i, (sample_idx, sample_class, *sample_time_series) in enumerate(samples_df.itertuples()):
#       3     ax = plt.subplot(num_classes, samples_per_class, i + 1)
#       4     ax.plot(range(len(sample_time_series)), sample_time_series, c=colors[sample_class-1])
#       5     axxticks
#
# NameError: name 'samples_df' is not defined

# %%
for row, inter_p in enumerate([0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]):
    for col, size in enumerate(['random', 'min', 'median', 'mean', 'max']):
        ax = plt.subplot(10, 10, (row)*10+col+1)
        
        ax.plot([0,1,2],[0,1,2])

# %%
0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45,
# Out:
# (0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45)

# %%
fig, axes = plt.subplots(6, 5, figsize=(17,15), tight_layout=True)
for row, inter_p in enumerate([0.05, 0.1, 0.15, 0.2, 0.25, 0.3]):
    for col, size in enumerate(['random', 'min', 'median', 'mean', 'max']):
        axes[row, col].plot([0,1,2],[0,1,2], label='shit1')
        axes[row, col].plot([0,1,2],[0,0.5,1], label='shit2')
        axes[row, col].plot([0,1,2],[1,1,1], label='shit3')
        #axes[row, col].set_title(f'P={inter_p:2f}, Size="{size}"')
        axes[row, col].set_xlabel('anom_m')
        axes[row, col].legend()
        
for ax, col in zip(axes[0], ['random', 'min', 'median', 'mean', 'max']):
    ax.set_title(f'Anom Comm Sizes="{col}"', fontsize=14)

for ax, row in zip(axes[:,0], [0.05, 0.1, 0.15, 0.2, 0.25, 0.3]):
    ax.set_ylabel(f'inter_p={row}', rotation=90, fontsize=16)
