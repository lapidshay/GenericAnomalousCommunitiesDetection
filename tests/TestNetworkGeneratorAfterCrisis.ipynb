# %% [markdown]
# # Test feature extraction

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.generators.random_graphs import erdos_renyi_graph, barabasi_albert_graph
from AnomalyInfusedCommunityStructuredRandomNetworkGenerator.AnomalyInfusedCommunityStructuredRandomNetworkGeneratorAfterCrisis import AnomalyInfusedCommunityStructuredRandomNetworkGenerator
import numpy as np
import random
import json
import seaborn as sns
# %matplotlib inline

# %%
norm_comm_alg = barabasi_albert_graph
anom_comm_alg = erdos_renyi_graph
p_inter = 0.5
k_min = 1
k_max = 1
random_seed=1

# %%
gen = AnomalyInfusedCommunityStructuredRandomNetworkGenerator(norm_comm_alg, anom_comm_alg, p_inter,k_min, k_max)

# %%
norm_comms = [10]*2
norm_m = 1
anom_comms = [10]*1
anom_p=1

# %%
g = gen.generate_network(norm_comms, norm_m, anom_comms, anom_p)

# %%
nx.draw(g, with_labels=True)

# %%
from AnomalousCommunityDetection.archive.Utils.GraphCommunityColorer import GraphCommunityColorer

# %%
colorere = GraphCommunityColorer(G, list(gen.get_partitions().items()), list(gen.get_partitions()))
colorere.color_node_original_community_attributes()

# %%
G.nodes(data=True)
